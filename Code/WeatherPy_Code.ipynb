# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
import urllib
import json
import openweathermapy.core as ow

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key


# Create empty lists to add the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
    # If no record found "skip" to next call
    except:
        print("City could not be found.")
    continue
# Out:
# Processing Record 1 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=albany
# City could not be found.
# Processing Record 2 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=waipawa
# Processing Record 3 | Verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=verkhoyansk
# Processing Record 4 | Tonantins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tonantins
# City could not be found.
# Processing Record 5 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=puerto ayora
# City could not be found.
# Processing Record 6 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=vaini
# Processing Record 7 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lavrentiya
# Processing Record 8 | Pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=pangody
# Processing Record 9 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=boa vista
# Processing Record 10 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mount gambier
# Processing Record 11 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mataura
# Processing Record 12 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nikolskoye
# Processing Record 13 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ushuaia
# Processing Record 14 | Killin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=killin
# Processing Record 15 | Paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=paita
# City could not be found.
# Processing Record 16 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=avarua
# Processing Record 17 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nouadhibou
# Processing Record 18 | Krasnoborsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=krasnoborsk
# Processing Record 19 | Sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sorong
# Processing Record 20 | Bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bundaberg
# Processing Record 21 | Ouallam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ouallam
# Processing Record 22 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=punta arenas
# Processing Record 23 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=busselton
# Processing Record 24 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=thompson
# Processing Record 25 | Jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=jacareacanga
# Processing Record 26 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=rikitea
# Processing Record 27 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=atuona
# Processing Record 28 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=cape town
# Processing Record 29 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mandalgovi
# Processing Record 30 | Linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=linxia
# Processing Record 31 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=isangel
# Processing Record 32 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=college
# Processing Record 33 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bredasdorp
# Processing Record 34 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=new norfolk
# Processing Record 35 | Biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=biltine
# Processing Record 36 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hobart
# Processing Record 37 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=cayenne
# Processing Record 38 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=belmonte
# Processing Record 39 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hermanus
# Processing Record 40 | Iquitos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=iquitos
# Processing Record 41 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=fortuna
# Processing Record 42 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sinnamary
# Processing Record 43 | Marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=marystown
# City could not be found.
# Processing Record 44 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=salalah
# Processing Record 45 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bluff
# Processing Record 46 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kodiak
# Processing Record 47 | Usogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=usogorsk
# Processing Record 48 | Douentza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=douentza
# Processing Record 49 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mayo
# Processing Record 50 | Key West
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=key west
# Processing Record 51 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=olinda
# Processing Record 52 | Ca Mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ca mau
# Processing Record 53 | Merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=merauke
# Processing Record 54 | Solana Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=solana beach
# Processing Record 55 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=seoul
# Processing Record 56 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=saint george
# City could not be found.
# Processing Record 57 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ilulissat
# Processing Record 58 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=souillac
# Processing Record 59 | Winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=winnemucca
# Processing Record 60 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sola
# Processing Record 61 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=upernavik
# Processing Record 62 | Taunggyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=taunggyi
# Processing Record 63 | Khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=khani
# Processing Record 64 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lasa
# Processing Record 65 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=srednekolymsk
# Processing Record 66 | Pekan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=pekan
# Processing Record 67 | Shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=shache
# Processing Record 68 | Aberdeen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=aberdeen
# City could not be found.
# Processing Record 69 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=naze
# Processing Record 70 | Utete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=utete
# Processing Record 71 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=jamestown
# Processing Record 72 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=flinders
# Processing Record 73 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kaitangata
# Processing Record 74 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kahului
# Processing Record 75 | Kochevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kochevo
# City could not be found.
# Processing Record 76 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=aklavik
# Processing Record 77 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=poum
# Processing Record 78 | Bonfim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bonfim
# Processing Record 79 | Marion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=marion
# Processing Record 80 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=saskylakh
# Processing Record 81 | Quesnel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=quesnel
# Processing Record 82 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dingle
# Processing Record 83 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=barrow
# Processing Record 84 | Mago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mago
# Processing Record 85 | Nola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nola
# Processing Record 86 | Bogo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bogo
# City could not be found.
# Processing Record 87 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ribeira grande
# Processing Record 88 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=goderich
# Processing Record 89 | Seymchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=seymchan
# Processing Record 90 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=petropavlovsk-kamchatskiy
# Processing Record 91 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=buala
# Processing Record 92 | Benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=benguela
# City could not be found.
# Processing Record 93 | Port Keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=port keats
# Processing Record 94 | Zalari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=zalari
# Processing Record 95 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=zhangye
# Processing Record 96 | Riohacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=riohacha
# Processing Record 97 | Shaowu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=shaowu
# Processing Record 98 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=coquimbo
# Processing Record 99 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sao filipe
# Processing Record 100 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lagoa
# Processing Record 101 | Teguldet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=teguldet
# Processing Record 102 | Nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nago
# Processing Record 103 | Demba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=demba
# Processing Record 104 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=port blair
# Processing Record 105 | Kaduqli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kaduqli
# Processing Record 106 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=narsaq
# Processing Record 107 | Nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nizwa
# Processing Record 108 | Nyimba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nyimba
# Processing Record 109 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=harper
# Processing Record 110 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=norman wells
# Processing Record 111 | Pitsunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=pitsunda
# Processing Record 112 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=east london
# Processing Record 113 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=walvis bay
# Processing Record 114 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=opuwo
# Processing Record 115 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=vestmanna
# Processing Record 116 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=yulara
# Processing Record 117 | Kirensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kirensk
# Processing Record 118 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hilo
# Processing Record 119 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=qaanaaq
# Processing Record 120 | Polovinnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=polovinnoye
# Processing Record 121 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=codrington
# Processing Record 122 | Kaniama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kaniama
# Processing Record 123 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=chokurdakh
# Processing Record 124 | Bloomingdale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bloomingdale
# Processing Record 125 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=grindavik
# Processing Record 126 | Pouembout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=pouembout
# Processing Record 127 | Marica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=marica
# Processing Record 128 | Oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=oranjemund
# Processing Record 129 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=castro
# City could not be found.
# Processing Record 130 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=katsuura
# Processing Record 131 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=san patricio
# Processing Record 132 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=port alfred
# Processing Record 133 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=carnarvon
# Processing Record 134 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=arraial do cabo
# Processing Record 135 | Okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=okha
# Processing Record 136 | Ambulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ambulu
# Processing Record 137 | Sao Jose da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sao jose da coroa grande
# Processing Record 138 | Alamogordo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=alamogordo
# Processing Record 139 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=beringovskiy
# Processing Record 140 | Drochia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=drochia
# Processing Record 141 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dikson
# City could not be found.
# Processing Record 142 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=san cristobal
# Processing Record 143 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=luganville
# Processing Record 144 | Rameshki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=rameshki
# Processing Record 145 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=saint-philippe
# Processing Record 146 | Mocuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mocuba
# Processing Record 147 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=rawson
# Processing Record 148 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=araouane
# Processing Record 149 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ancud
# Processing Record 150 | Campeche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=campeche
# Processing Record 151 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=cidreira
# Processing Record 152 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=noumea
# Processing Record 153 | Da Lat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=da lat
# Processing Record 154 | Wagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=wagar
# Processing Record 155 | Marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=marsaxlokk
# Processing Record 156 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=port elizabeth
# Processing Record 157 | Chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=chumikan
# Processing Record 158 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=vostok
# City could not be found.
# Processing Record 159 | Nyrob
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nyrob
# Processing Record 160 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=torbay
# Processing Record 161 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=geraldton
# Processing Record 162 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=karratha
# City could not be found.
# Processing Record 163 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=vardo
# Processing Record 164 | Arica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=arica
# Processing Record 165 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=alta floresta
# Processing Record 166 | Pincher Creek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=pincher creek
# City could not be found.
# Processing Record 167 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=moose factory
# Processing Record 168 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lata
# Processing Record 169 | Chiredzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=chiredzi
# Processing Record 170 | Dengzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dengzhou
# City could not be found.
# Processing Record 171 | Pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=pathein
# Processing Record 172 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=moron
# City could not be found.
# Processing Record 173 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=namatanai
# City could not be found.
# Processing Record 174 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=saint-pierre
# City could not be found.
# Processing Record 175 | Puerto Cabezas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=puerto cabezas
# Processing Record 176 | Sawakin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sawakin
# Processing Record 177 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nemuro
# Processing Record 178 | Tsabong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tsabong
# City could not be found.
# Processing Record 179 | Bam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bam
# City could not be found.
# Processing Record 180 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bambous virieux
# Processing Record 181 | Dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dudinka
# City could not be found.
# City could not be found.
# City could not be found.
# Processing Record 182 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=touros
# Processing Record 183 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dunedin
# City could not be found.
# Processing Record 184 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kamenka
# Processing Record 185 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=shimoda
# City could not be found.
# Processing Record 186 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tasiilaq
# Processing Record 187 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tiksi
# Processing Record 188 | Ailigandi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ailigandi
# Processing Record 189 | Ozu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ozu
# Processing Record 190 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=yellowknife
# Processing Record 191 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=husavik
# Processing Record 192 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kapaa
# Processing Record 193 | Aba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=aba
# Processing Record 194 | Sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sangar
# Processing Record 195 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kirakira
# Processing Record 196 | Ust-Omchug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ust-omchug
# Processing Record 197 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=padang
# Processing Record 198 | Eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=eureka
# Processing Record 199 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=butaritari
# Processing Record 200 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=airai
# Processing Record 201 | Honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=honiara
# Processing Record 202 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mar del plata
# City could not be found.
# Processing Record 203 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=talcahuano
# Processing Record 204 | Qujing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=qujing
# Processing Record 205 | Christiana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=christiana
# Processing Record 206 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=atar
# Processing Record 207 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=constitucion
# Processing Record 208 | Kingston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kingston
# Processing Record 209 | Ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ambon
# Processing Record 210 | Bar-le-Duc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bar-le-duc
# Processing Record 211 | Mangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mangai
# Processing Record 212 | Tollose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tollose
# City could not be found.
# Processing Record 213 | Ust-Ilimsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ust-ilimsk
# Processing Record 214 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tuktoyaktuk
# Processing Record 215 | Novopokrovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=novopokrovka
# Processing Record 216 | Halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=halifax
# Processing Record 217 | Kanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kanda
# Processing Record 218 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=berlevag
# Processing Record 219 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=esperance
# Processing Record 220 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sept-iles
# Processing Record 221 | Jijiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=jijiga
# Processing Record 222 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=provideniya
# Processing Record 223 | Mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mayumba
# Processing Record 224 | Herat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=herat
# Processing Record 225 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=carutapera
# Processing Record 226 | Zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=zhangjiakou
# Processing Record 227 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=paamiut
# Processing Record 228 | Abu Kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=abu kamal
# Processing Record 229 | Kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kutum
# City could not be found.
# Processing Record 230 | San Jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=san jose
# Processing Record 231 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kaeo
# Processing Record 232 | Carros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=carros
# Processing Record 233 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=iqaluit
# Processing Record 234 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hovd
# Processing Record 235 | Sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sorland
# Processing Record 236 | Kampot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kampot
# Processing Record 237 | Nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nara
# Processing Record 238 | Bobcaygeon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bobcaygeon
# Processing Record 239 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=rome
# Processing Record 240 | Campbell River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=campbell river
# Processing Record 241 | Ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ornskoldsvik
# City could not be found.
# Processing Record 242 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bethel
# Processing Record 243 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tura
# Processing Record 244 | Porto Walter
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=porto walter
# Processing Record 245 | Orlik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=orlik
# Processing Record 246 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ponta do sol
# Processing Record 247 | Arys
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=arys
# Processing Record 248 | Dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dauphin
# Processing Record 249 | Oak Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=oak harbor
# Processing Record 250 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=luderitz
# City could not be found.
# Processing Record 251 | Novyy Svit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=novyy svit
# Processing Record 252 | Golfito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=golfito
# Processing Record 253 | Dawlatabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dawlatabad
# Processing Record 254 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=port-gentil
# Processing Record 255 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=arlit
# Processing Record 256 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lompoc
# Processing Record 257 | Warrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=warrington
# Processing Record 258 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=faanui
# Processing Record 259 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=vanimo
# Processing Record 260 | Swan Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=swan hill
# City could not be found.
# Processing Record 261 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=wanning
# Processing Record 262 | Busca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=busca
# Processing Record 263 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=longyearbyen
# City could not be found.
# Processing Record 264 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sitka
# Processing Record 265 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=matara
# City could not be found.
# Processing Record 266 | Muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=muisne
# Processing Record 267 | Lakes Entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lakes entrance
# Processing Record 268 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=fairbanks
# Processing Record 269 | Koson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=koson
# Processing Record 270 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=port macquarie
# Processing Record 271 | Kerouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kerouane
# Processing Record 272 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sechura
# City could not be found.
# Processing Record 273 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nanortalik
# Processing Record 274 | Felanitx
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=felanitx
# Processing Record 275 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=port lincoln
# Processing Record 276 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=rio gallegos
# City could not be found.
# Processing Record 277 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lebu
# Processing Record 278 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tautira
# Processing Record 279 | Peruibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=peruibe
# Processing Record 280 | Puerto Maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=puerto maldonado
# Processing Record 281 | Edson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=edson
# Processing Record 282 | Kastamonu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kastamonu
# City could not be found.
# Processing Record 283 | Boda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=boda
# Processing Record 284 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=margate
# Processing Record 285 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=taoudenni
# Processing Record 286 | Santa Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=santa cruz
# Processing Record 287 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=te anau
# Processing Record 288 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=north bend
# Processing Record 289 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=los llanos de aridane
# Processing Record 290 | Iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=iskateley
# Processing Record 291 | Yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=yanam
# Processing Record 292 | Rafraf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=rafraf
# Processing Record 293 | Mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mana
# Processing Record 294 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=broken hill
# Processing Record 295 | Kholtoson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kholtoson
# City could not be found.
# Processing Record 296 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=riyadh
# Processing Record 297 | Caiaponia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=caiaponia
# Processing Record 298 | Santa Vitoria do Palmar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=santa vitoria do palmar
# Processing Record 299 | Bani Walid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bani walid
# Processing Record 300 | Aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=aquiraz
# Processing Record 301 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kavaratti
# Processing Record 302 | Terra Boa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=terra boa
# Processing Record 303 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=khatanga
# Processing Record 304 | Barahona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=barahona
# Processing Record 305 | Waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=waddan
# Processing Record 306 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=cabo san lucas
# Processing Record 307 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=san quintin
# Processing Record 308 | Dagana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dagana
# Processing Record 309 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=avera
# Processing Record 310 | Zelenogorskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=zelenogorskiy
# Processing Record 311 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mahebourg
# City could not be found.
# Processing Record 312 | Dawei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dawei
# Processing Record 313 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=victoria
# Processing Record 314 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=marawi
# Processing Record 315 | Klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=klyuchi
# Processing Record 316 | Klyuchevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=klyuchevskiy
# Processing Record 317 | Elda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=elda
# Processing Record 318 | Hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hailar
# City could not be found.
# Processing Record 319 | Taseyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=taseyevo
# Processing Record 320 | Lamu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lamu
# Processing Record 321 | Hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hit
# Processing Record 322 | Whitecourt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=whitecourt
# Processing Record 323 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=severo-kurilsk
# Processing Record 324 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=deputatskiy
# Processing Record 325 | Strezhevoy
# ...
# Processing Record 474 | San Angelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=san angelo
# Processing Record 475 | Carrickmacross
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=carrickmacross
# Processing Record 476 | Adiake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=adiake
# Processing Record 477 | Athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=athabasca
# Processing Record 478 | Muswellbrook
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=muswellbrook
# Processing Record 479 | Uvarovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=uvarovka
# Processing Record 480 | Kattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kattivakkam
# Processing Record 481 | Oum Hadjer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=oum hadjer
# Processing Record 482 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hambantota
# Processing Record 483 | Anamur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=anamur
# Processing Record 484 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kalmunai
# Processing Record 485 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=egvekinot
# City could not be found.
# Processing Record 486 | Sapele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sapele
# Processing Record 487 | Cicero Dantas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=cicero dantas
# Processing Record 488 | Ati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ati
# Processing Record 489 | Singureni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=singureni
# Processing Record 490 | Vlasim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=vlasim
# Processing Record 491 | Grafton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=grafton
# Processing Record 492 | Huntington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=huntington
# Processing Record 493 | Ribnitz-Damgarten
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ribnitz-damgarten
# Processing Record 494 | Dongobesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dongobesh
# Processing Record 495 | Ayagoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ayagoz
# Processing Record 496 | Ladnun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ladnun
# Processing Record 497 | Shwebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=shwebo
# City could not be found.
# City could not be found.
# Processing Record 498 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bandarbeyla
# Processing Record 499 | Aleksandrov Gay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=aleksandrov gay
# Processing Record 500 | Santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=santiago
# Processing Record 501 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=chuy
# Processing Record 502 | La Crosse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=la crosse
# Processing Record 503 | Vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=vrangel
# Processing Record 504 | Genc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=genc
# Processing Record 505 | Minudasht
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=minudasht
# Processing Record 506 | Biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=biak
# City could not be found.
# Processing Record 507 | Reitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=reitz
# City could not be found.
# Processing Record 508 | Tonawanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tonawanda
# City could not be found.
# Processing Record 509 | Maralal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=maralal
# Processing Record 510 | Garissa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=garissa
# Processing Record 511 | Pokhara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=pokhara
# Processing Record 512 | Kandalaksha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kandalaksha
# Processing Record 513 | Sao Luiz Gonzaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=sao luiz gonzaga
# Processing Record 514 | Tapes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tapes
# Processing Record 515 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bubaque
# Processing Record 516 | Awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=awbari
# Processing Record 517 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=muros
# Processing Record 518 | Daura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=daura
# Processing Record 519 | Hermiston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hermiston
# City could not be found.
# Processing Record 520 | Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nelson
# Processing Record 521 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=port-cartier
# Processing Record 522 | Taphan Hin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=taphan hin
# Processing Record 523 | Kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kokopo
# Processing Record 524 | Jiaonan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=jiaonan
# Processing Record 525 | Lenger
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lenger
# Processing Record 526 | Labe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=labe
# Processing Record 527 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bilibino
# Processing Record 528 | Labytnangi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=labytnangi
# Processing Record 529 | Omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=omsukchan
# City could not be found.
# Processing Record 530 | Villaviciosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=villaviciosa
# Processing Record 531 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=grand gaube
# Processing Record 532 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=plettenberg bay
# Processing Record 533 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bonthe
# Processing Record 534 | Ozinki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ozinki
# Processing Record 535 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=tual
# Processing Record 536 | Atbasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=atbasar
# Processing Record 537 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=beloha
# Processing Record 538 | Dobson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dobson
# Processing Record 539 | Novobirilyussy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=novobirilyussy
# Processing Record 540 | Ishinomaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ishinomaki
# Processing Record 541 | Daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=daru
# Processing Record 542 | Bucerias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bucerias
# Processing Record 543 | Galeana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=galeana
# Processing Record 544 | Grand-Santi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=grand-santi
# Processing Record 545 | Krutinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=krutinka
# Processing Record 546 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=georgetown
# Processing Record 547 | Suda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=suda
# Processing Record 548 | Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bud
# Processing Record 549 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nome
# Processing Record 550 | Lerwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lerwick
# Processing Record 551 | Mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=mnogovershinnyy
# Processing Record 552 | Bacolod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bacolod
# Processing Record 553 | Dispur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dispur
# Processing Record 554 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=broome
# Processing Record 555 | Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=dwarka
# Processing Record 556 | Gasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=gasa
# Processing Record 557 | Jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=jumla
# Processing Record 558 | Calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=calvinia
# Processing Record 559 | Kulob
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=kulob
# Processing Record 560 | Wlingi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=wlingi
# Processing Record 561 | Galveston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=galveston
# Processing Record 562 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hasaki
# Processing Record 563 | Cape Canaveral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=cape canaveral
# Processing Record 564 | Traralgon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=traralgon
# Processing Record 565 | Ontario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=ontario
# Processing Record 566 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=bathsheba
# Processing Record 567 | Neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=neiafu
# Processing Record 568 | Nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=nadym
# Processing Record 569 | Charlestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=charlestown
# Processing Record 570 | Gewane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=gewane
# Processing Record 571 | Casas Grandes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=casas grandes
# Processing Record 572 | Lyubinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=lyubinskiy
# Processing Record 573 | Stoke-on-Trent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=stoke-on-trent
# Processing Record 574 | el Prat de Llobregat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=el prat de llobregat
# Processing Record 575 | Camapua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=camapua
# Processing Record 576 | Gdynia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=gdynia
# Processing Record 577 | Hopkinsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=hopkinsville
# City could not be found.
# Processing Record 578 | Boyuibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=boyuibe
# Processing Record 579 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=pacific grove
# Processing Record 580 | Warmbad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=warmbad
# Processing Record 581 | Wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a5b2e5bd1fca78af4dd828fc8df2ca84&q=wuwei

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()

# Save data frame to CSV
weather_data.to_csv('weather_data.csv')

# Display data frame head 
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Albany          90      US  1551921267        72  42.65  -73.75
# 1       Waipawa           0      NZ  1551918556        41 -39.94  176.59
# 2   Verkhoyansk          80      RU  1551921441        72  67.55  133.39
# 3     Tonantins          20      BR  1551921441        59  -2.86  -67.77
# 4  Puerto Ayora          20      EC  1551916800        78  -0.74  -90.35
#
#    Max Temp  Wind Speed
# 0     17.60       11.41
# 1     80.01        1.99
# 2    -11.89        3.74
# 3     87.16        7.65
# 4     80.60        6.93

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Max Temperature")
plt.ylabel("Maximum Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
